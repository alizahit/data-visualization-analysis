# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
plt.style.use('seaborn-deep')

# %%
df=pd.read_csv(r"C:\Users\aliza\Untitled Folder\Fish.csv")
df
# Out:
#     Species  Weight  Length1  Length2  Length3   Height   Width
# 0     Bream   242.0     23.2     25.4     30.0  11.5200  4.0200
# 1     Bream   290.0     24.0     26.3     31.2  12.4800  4.3056
# 2     Bream   340.0     23.9     26.5     31.1  12.3778  4.6961
# 3     Bream   363.0     26.3     29.0     33.5  12.7300  4.4555
# 4     Bream   430.0     26.5     29.0     34.0  12.4440  5.1340
# ..      ...     ...      ...      ...      ...      ...     ...
# 154   Smelt    12.2     11.5     12.2     13.4   2.0904  1.3936
# 155   Smelt    13.4     11.7     12.4     13.5   2.4300  1.2690
# 156   Smelt    12.2     12.1     13.0     13.8   2.2770  1.2558
# 157   Smelt    19.7     13.2     14.3     15.2   2.8728  2.0672
# 158   Smelt    19.9     13.8     15.0     16.2   2.9322  1.8792
#
# [159 rows x 7 columns]

# %%
df2=df.groupby('Species').mean()

# %%
df2['Species']=df2.index
df2.index=range(len(df2['Weight']))

# %%
df_bream=df.loc[df['Species']=='Bream']
df_perch=df.loc[df['Species']=='Perch']

# %%
fig=plt.figure()
###
fig.add_subplot(3,1,1).set_title('Türlere '
                        'Göre Balık Genişliği',fontdict={'fontsize':10})
plt.bar(df2['Species'],df2['Width'],.4)
###                                 
fig.add_subplot(3,2,3).set_title('Bream Türü '
                        'Genişliği Histogramı',fontdict={'fontsize':10})
plt.hist(df_bream['Width'],rwidth=.9)
###
fig.add_subplot(3,2,4).set_title('Parkki Türü '
                         'Genişliği Histogramı',fontdict={'fontsize':10})
plt.hist(df_perch['Width'],rwidth=.9)
# Out:
# (array([ 2.,  2.,  8., 15.,  9.,  1.,  2.,  5.,  8.,  4.]),
#  array([1.408 , 2.0814, 2.7548, 3.4282, 4.1016, 4.775 , 5.4484, 6.1218,
#         6.7952, 7.4686, 8.142 ]),
#  <BarContainer object of 10 artists>)

# %%
fig.tight_layout()
fig.savefig(fname='tablo1.jpg',format='jpg')

# %%
fig2=plt.figure()
###
fig2.add_subplot(1,1,1).set_title('Bream & Parkki Dağılım Grafiği')
plt.scatter(x=df_bream['Height'],y=df_bream['Width'])
plt.scatter(x=df_parkki['Height'],y=df_parkki['Width'])

plt.xlabel('Uzunluk (cm)',fontdict={'fontsize':10})
plt.ylabel('Genişlik (cm)',fontdict={'fontsize':10})
plt.legend(['Bream','Parkki'],loc='lower right')

# %%
fig2.tight_layout()
fig2.savefig(fname='tablo2.jpg',format='jpg')
